# %%
#to open file in read binary mode
import pickle

# %%
#to open exiting file in read mode
file1=open("model.pkl","rb")#rb means read binary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-58b4e760750d> in <module>
#       1 #to open exiting file in read mode
# ----> 2 file1=open("model.pkl","rb")#rb means read binary
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'

# %%
#to read data from file1, use load() inbuilt method of pickle
model=pickle.load(file1) #model is user defined object

# %%
#to find the salary of those employee who have year of experience
sep_len=float(input("sepal_length :-  "))
sep_wid=float(input("sepal_width :-  "))
pet_len=float(input("petal_length :-  "))
pet_wid=float(input("petal_width :-  "))
#print(type(exp))#check input datatype because always model takes 2D 
#first convert input exp into 2D array
import numpy as np
sep_len=np.array([[sep_len]])#2D menas [[]]
sep_wid=np.array([[sep_wid]])
pet_len=np.array([[pet_len]])
pet_wid=np.array([[pet_wid]])
print(type(sep_len))
print(type(sep_wid))
print(type(pet_len))
print(type(pet_wid))
#print(exp.ndim)
Y_pred=model.predict(sep_len)
Y_pred=model.predict(sep_wid)
Y_pred=model.predict(pet_len)
Y_pred=model.predict(pet_wid)
print("predicted Species : - ",Y_pred)
